# %%
import os

# %%
raw_data_folder = r"X:\AGDrive\ADA-Timeseries project\Raw_Data"
predicted_data_folder = r"X:\AGDrive\ADA-Timeseries project\Pred_Data"
lagging_data_folder = r"X:\AGDrive\ADA-Timeseries project\Lag_Data"

# --- Top 10 NSE Indices (Yahoo Finance symbols) ---
nse_indices = [
    "^NSEI",          # Nifty 50
    "^NSEBANK",       # Nifty Bank
    "^CNXIT",         # Nifty IT
    "^CNXPHARMA",     # Nifty Pharma
    "^CNXFMCG",       # Nifty FMCG
    "^CNXAUTO",       # Nifty Auto
    "^CNXMETAL",      # Nifty Metal
    "^CNXREALTY",     # Nifty Realty
    "^CNXENERGY",     # Nifty Energy
    "NIFTY_FIN_SERVICE.NS"     # Nifty Financial Services
]

# --- Top 10 NSE Stocks (as per popularity / large-cap) ---
nse_stocks = [
    "RELIANCE.NS",
    "TCS.NS",
    "SUNPHARMA.NS",
    "ICICIBANK.NS",
    "INFY.NS",
    "SBIN.NS",
    "BHARTIARTL.NS",
    "ITC.NS",
    "LT.NS",
    "HINDUNILVR.NS"
]

# --- Combine all tickers ---"SUNPHARMA.NS": "SUNPHARMA",
all_tickers = nse_indices + nse_stocks

# %%
from update_data_util import fetch_and_update_stock_data, update_predictions_file
# --- Fetch and update data for all tickers ---
for ticker in all_tickers:
    print(f"\n{'='*80}")
    print(f"📊 Processing: {ticker}")
    try:
        fetch_and_update_stock_data(ticker_symbol=ticker, data_dir=raw_data_folder)
    except Exception as e:
        print(f"❌ Error fetching {ticker}: {e}")
# Out:
# ================================================================================
# 📊 Processing: ^NSEI
# 📈 Updating existing data for NIFTY_50...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^NSEBANK
# 📈 Updating existing data for NIFTY_BANK...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXIT
# 📈 Updating existing data for NIFTY_IT...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXPHARMA
# 📈 Updating existing data for NIFTY_PHARMA...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXFMCG
# 📈 Updating existing data for NIFTY_FMCG...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXAUTO
# 📈 Updating existing data for NIFTY_AUTO...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXMETAL
# 📈 Updating existing data for NIFTY_METAL...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXREALTY
# 📈 Updating existing data for NIFTY_REALTY...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ^CNXENERGY
# 📈 Updating existing data for NIFTY_ENERGY...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: NIFTY_FIN_SERVICE.NS
# 📈 Updating existing data for NIFTY_FIN_SERVICE...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: RELIANCE.NS
# 📈 Updating existing data for RELIANCE_INDUSTRIES_LTD...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: TCS.NS
# 📈 Updating existing data for TATA_CONSULTANCY_SERV_LT...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: SUNPHARMA.NS
# 📦 No existing data found. Fetching full 2y history for SUN_PHARMACEUTICAL_IND_L...
# 🧹 Header cleaned and new header inserted in 'SUN_PHARMACEUTICAL_IND_L_data.csv'.
# ✅ Data downloaded and saved to: 'X:\AGDrive\ADA-Timeseries project\Raw_Data\SUN_PHARMACEUTICAL_IND_L_data.csv'
# 📊 Saved 3425 records
#
# ================================================================================
# 📊 Processing: ICICIBANK.NS
# 📈 Updating existing data for ICICI_BANK_LTD....
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: INFY.NS
# 📈 Updating existing data for INFOSYS_LIMITED...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: SBIN.NS
# 📈 Updating existing data for STATE_BANK_OF_INDIA...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: BHARTIARTL.NS
# 📈 Updating existing data for BHARTI_AIRTEL_LIMITED...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: ITC.NS
# 📈 Updating existing data for ITC_LTD...
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: LT.NS
# 📈 Updating existing data for LARSEN_&_TOUBRO_LTD....
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records
#
# ================================================================================
# 📊 Processing: HINDUNILVR.NS
# 📈 Updating existing data for HINDUSTAN_UNILEVER_LTD....
# Last record in file is from: 2025-11-12 10:15:00+05:30
# ✅ Data updated from 2025-11-12 11:15:00+05:30 to 2025-11-17 15:15:00+05:30
# 📊 Added 26 new records

# %%
ticker_to_basename = {
    # Indices
    "^NSEI": "NIFTY_50",
    "^NSEBANK": "NIFTY_BANK",
    "^CNXIT": "NIFTY_IT",
    "^CNXPHARMA": "NIFTY_PHARMA",
    "^CNXFMCG": "NIFTY_FMCG",
    "^CNXAUTO": "NIFTY_AUTO",
    "^CNXMETAL": "NIFTY_METAL",
    "^CNXREALTY": "NIFTY_REALTY",
    "^CNXENERGY": "NIFTY_ENERGY",
    "NIFTY_FIN_SERVICE.NS": "NIFTY_FIN_SERVICE",
    
    # Stocks
    "RELIANCE.NS": "RELIANCE_INDUSTRIES_LTD",
    "TCS.NS": "TATA_CONSULTANCY_SERV_LT", # Matched from your image
    "SUNPHARMA.NS": "SUN_PHARMACEUTICAL_IND_L",
    "ICICIBANK.NS": "ICICI_BANK_LTD.",
    "INFY.NS": "INFOSYS_LIMITED",
    "SBIN.NS": "STATE_BANK_OF_INDIA",
    "BHARTIARTL.NS": "BHARTI_AIRTEL_LIMITED",
    "ITC.NS": "ITC_LTD",
    "LT.NS": "LARSEN_&_TOUBRO_LTD.",
    "HINDUNILVR.NS": "HINDUSTAN_UNILEVER_LTD."
}

all_tickers = list(ticker_to_basename.keys())

# %% [markdown]
# # -----------------  XGBoost ---------------------

# %%
print(f"\n{'='*80}")
print(f"🔮 Generating predictions for all equities...")

for ticker, basename in ticker_to_basename.items():
    print(f"---> Processing {basename}")
    
    try:
        # 1. Construct the path to the raw data file (Input)
        raw_file_name = f"{basename}_data.csv"
        raw_file_path = os.path.join(raw_data_folder, raw_file_name)
        
        # 2. Construct the path for the new prediction file (Output)
        # Follows your "Equity+prediction+xgboost" format
        pred_file_name = f"{basename}_predictions_xgboost.csv"
        pred_file_path = os.path.join(predicted_data_folder, pred_file_name)
        
        # 3. Call the function (as you assumed)
        update_predictions_file(raw_file_path, pred_file_path)
        print(f"    ✅ Successfully updated: {pred_file_name}")
    
    except Exception as e:
        print(f"    ❌ Error processing prediction for {basename}: {e}")

print("\nAll processing complete.")
# Out:
# ================================================================================
# 🔮 Generating predictions for all equities...
# ---> Processing NIFTY_50
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_50_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_50_predictions_xgboost.csv
# ---> Processing NIFTY_BANK
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_BANK_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_BANK_predictions_xgboost.csv
# ---> Processing NIFTY_IT
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_IT_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_IT_predictions_xgboost.csv
# ---> Processing NIFTY_PHARMA
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_PHARMA_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_PHARMA_predictions_xgboost.csv
# ---> Processing NIFTY_FMCG
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_FMCG_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_FMCG_predictions_xgboost.csv
# ---> Processing NIFTY_AUTO
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_AUTO_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_AUTO_predictions_xgboost.csv
# ---> Processing NIFTY_METAL
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_METAL_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_METAL_predictions_xgboost.csv
# ---> Processing NIFTY_REALTY
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_REALTY_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_REALTY_predictions_xgboost.csv
# ---> Processing NIFTY_ENERGY
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_ENERGY_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_ENERGY_predictions_xgboost.csv
# ---> Processing NIFTY_FIN_SERVICE
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_FIN_SERVICE_predictions_xgboost.csv
#     ✅ Successfully updated: NIFTY_FIN_SERVICE_predictions_xgboost.csv
# ---> Processing RELIANCE_INDUSTRIES_LTD
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\RELIANCE_INDUSTRIES_LTD_predictions_xgboost.csv
#     ✅ Successfully updated: RELIANCE_INDUSTRIES_LTD_predictions_xgboost.csv
# ---> Processing TATA_CONSULTANCY_SERV_LT
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\TATA_CONSULTANCY_SERV_LT_predictions_xgboost.csv
#     ✅ Successfully updated: TATA_CONSULTANCY_SERV_LT_predictions_xgboost.csv
# ---> Processing HDFC_BANK_LTD
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\HDFC_BANK_LTD_predictions_xgboost.csv
#     ✅ Successfully updated: HDFC_BANK_LTD_predictions_xgboost.csv
# ---> Processing ICICI_BANK_LTD.
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\ICICI_BANK_LTD._predictions_xgboost.csv
#     ✅ Successfully updated: ICICI_BANK_LTD._predictions_xgboost.csv
# ---> Processing INFOSYS_LIMITED
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\INFOSYS_LIMITED_predictions_xgboost.csv
#     ✅ Successfully updated: INFOSYS_LIMITED_predictions_xgboost.csv
# ---> Processing STATE_BANK_OF_INDIA
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\STATE_BANK_OF_INDIA_predictions_xgboost.csv
#     ✅ Successfully updated: STATE_BANK_OF_INDIA_predictions_xgboost.csv
# ---> Processing BHARTI_AIRTEL_LIMITED
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\BHARTI_AIRTEL_LIMITED_predictions_xgboost.csv
#     ✅ Successfully updated: BHARTI_AIRTEL_LIMITED_predictions_xgboost.csv
# ---> Processing ITC_LTD
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\ITC_LTD_predictions_xgboost.csv
#     ✅ Successfully updated: ITC_LTD_predictions_xgboost.csv
# ---> Processing LARSEN_&_TOUBRO_LTD.
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\LARSEN_&_TOUBRO_LTD._predictions_xgboost.csv
#     ✅ Successfully updated: LARSEN_&_TOUBRO_LTD._predictions_xgboost.csv
# ---> Processing HINDUSTAN_UNILEVER_LTD.
# Appended 2 new entries to X:\AGDrive\ADA-Timeseries project\Pred_Data\HINDUSTAN_UNILEVER_LTD._predictions_xgboost.csv
#     ✅ Successfully updated: HINDUSTAN_UNILEVER_LTD._predictions_xgboost.csv
#
# All processing complete.

# %% [markdown]
# # ---------------- Random Forest ------------------------

# %%
# print(f"\n{'='*80}")
# print(f"🔮 Generating predictions for all equities...")

# for ticker, basename in ticker_to_basename.items():
#     print(f"---> Processing {basename}")
    
#     try:
#         # 1. Construct the path to the raw data file (Input)
#         raw_file_name = f"{basename}_data.csv"
#         raw_file_path = os.path.join(raw_data_folder, raw_file_name)
        
#         # 2. Construct the path for the new prediction file (Output)
#         # Follows your "Equity+prediction+xgboost" format
#         pred_file_name = f"{basename}_predictions_rf.csv"
#         pred_file_path = os.path.join(predicted_data_folder, pred_file_name)
        
#         # 3. Call the function (as you assumed)
#         update_predictions_file(raw_file_path, pred_file_path)
#         print(f"    ✅ Successfully updated: {pred_file_name}")
    
#     except Exception as e:
#         print(f"    ❌ Error processing prediction for {basename}: {e}")

# print("\nAll processing complete.")
# Out:
# ================================================================================
# 🔮 Generating predictions for all equities...
# ---> Processing NIFTY_50
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_50_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_50_predictions_rf.csv
# ---> Processing NIFTY_BANK
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_BANK_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_BANK_predictions_rf.csv
# ---> Processing NIFTY_IT
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_IT_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_IT_predictions_rf.csv
# ---> Processing NIFTY_PHARMA
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_PHARMA_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_PHARMA_predictions_rf.csv
# ---> Processing NIFTY_FMCG
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_FMCG_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_FMCG_predictions_rf.csv
# ---> Processing NIFTY_AUTO
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_AUTO_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_AUTO_predictions_rf.csv
# ---> Processing NIFTY_METAL
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_METAL_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_METAL_predictions_rf.csv
# ---> Processing NIFTY_REALTY
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_REALTY_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_REALTY_predictions_rf.csv
# ---> Processing NIFTY_ENERGY
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_ENERGY_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_ENERGY_predictions_rf.csv
# ---> Processing NIFTY_FIN_SERVICE
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_FIN_SERVICE_predictions_rf.csv with all data.
#     ✅ Successfully updated: NIFTY_FIN_SERVICE_predictions_rf.csv
# ---> Processing RELIANCE_INDUSTRIES_LTD
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\RELIANCE_INDUSTRIES_LTD_predictions_rf.csv with all data.
#     ✅ Successfully updated: RELIANCE_INDUSTRIES_LTD_predictions_rf.csv
# ---> Processing TATA_CONSULTANCY_SERV_LT
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\TATA_CONSULTANCY_SERV_LT_predictions_rf.csv with all data.
#     ✅ Successfully updated: TATA_CONSULTANCY_SERV_LT_predictions_rf.csv
# ---> Processing HDFC_BANK_LTD
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\HDFC_BANK_LTD_predictions_rf.csv with all data.
#     ✅ Successfully updated: HDFC_BANK_LTD_predictions_rf.csv
# ---> Processing ICICI_BANK_LTD.
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\ICICI_BANK_LTD._predictions_rf.csv with all data.
#     ✅ Successfully updated: ICICI_BANK_LTD._predictions_rf.csv
# ---> Processing INFOSYS_LIMITED
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\INFOSYS_LIMITED_predictions_rf.csv with all data.
#     ✅ Successfully updated: INFOSYS_LIMITED_predictions_rf.csv
# ---> Processing STATE_BANK_OF_INDIA
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\STATE_BANK_OF_INDIA_predictions_rf.csv with all data.
#     ✅ Successfully updated: STATE_BANK_OF_INDIA_predictions_rf.csv
# ---> Processing BHARTI_AIRTEL_LIMITED
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\BHARTI_AIRTEL_LIMITED_predictions_rf.csv with all data.
#     ✅ Successfully updated: BHARTI_AIRTEL_LIMITED_predictions_rf.csv
# ---> Processing ITC_LTD
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\ITC_LTD_predictions_rf.csv with all data.
#     ✅ Successfully updated: ITC_LTD_predictions_rf.csv
# ---> Processing LARSEN_&_TOUBRO_LTD.
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\LARSEN_&_TOUBRO_LTD._predictions_rf.csv with all data.
#     ✅ Successfully updated: LARSEN_&_TOUBRO_LTD._predictions_rf.csv
# ---> Processing HINDUSTAN_UNILEVER_LTD.
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\HINDUSTAN_UNILEVER_LTD._predictions_rf.csv with all data.
#     ✅ Successfully updated: HINDUSTAN_UNILEVER_LTD._predictions_rf.csv
#
# All processing complete.

# %% [markdown]
# # ------------------ lSTM --------------

# %%
# print(f"\n{'='*80}")
# print(f"🔮 Generating predictions for all equities...")

# for ticker, basename in ticker_to_basename.items():
#     print(f"---> Processing {basename}")
    
#     try:
#         # 1. Construct the path to the raw data file (Input)
#         raw_file_name = f"{basename}_data.csv"
#         raw_file_path = os.path.join(raw_data_folder, raw_file_name)
        
#         # 2. Construct the path for the new prediction file (Output)
#         # Follows your "Equity+prediction+xgboost" format
#         pred_file_name = f"{basename}_predictions_lstm.csv"
#         pred_file_path = os.path.join(predicted_data_folder, pred_file_name)
        
#         # 3. Call the function (as you assumed)
#         update_predictions_file(raw_file_path, pred_file_path)
#         print(f"    ✅ Successfully updated: {pred_file_name}")
    
#     except Exception as e:
#         print(f"    ❌ Error processing prediction for {basename}: {e}")

# print("\nAll processing complete.")
# Out:
# ================================================================================
# 🔮 Generating predictions for all equities...
# ---> Processing NIFTY_50
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_50_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_50_predictions_lstm.csv
# ---> Processing NIFTY_BANK
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_BANK_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_BANK_predictions_lstm.csv
# ---> Processing NIFTY_IT
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_IT_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_IT_predictions_lstm.csv
# ---> Processing NIFTY_PHARMA
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_PHARMA_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_PHARMA_predictions_lstm.csv
# ---> Processing NIFTY_FMCG
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_FMCG_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_FMCG_predictions_lstm.csv
# ---> Processing NIFTY_AUTO
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_AUTO_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_AUTO_predictions_lstm.csv
# ---> Processing NIFTY_METAL
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_METAL_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_METAL_predictions_lstm.csv
# ---> Processing NIFTY_REALTY
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_REALTY_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_REALTY_predictions_lstm.csv
# ---> Processing NIFTY_ENERGY
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_ENERGY_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_ENERGY_predictions_lstm.csv
# ---> Processing NIFTY_FIN_SERVICE
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\NIFTY_FIN_SERVICE_predictions_lstm.csv with all data.
#     ✅ Successfully updated: NIFTY_FIN_SERVICE_predictions_lstm.csv
# ---> Processing RELIANCE_INDUSTRIES_LTD
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\RELIANCE_INDUSTRIES_LTD_predictions_lstm.csv with all data.
#     ✅ Successfully updated: RELIANCE_INDUSTRIES_LTD_predictions_lstm.csv
# ---> Processing TATA_CONSULTANCY_SERV_LT
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\TATA_CONSULTANCY_SERV_LT_predictions_lstm.csv with all data.
#     ✅ Successfully updated: TATA_CONSULTANCY_SERV_LT_predictions_lstm.csv
# ---> Processing HDFC_BANK_LTD
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\HDFC_BANK_LTD_predictions_lstm.csv with all data.
#     ✅ Successfully updated: HDFC_BANK_LTD_predictions_lstm.csv
# ---> Processing ICICI_BANK_LTD.
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\ICICI_BANK_LTD._predictions_lstm.csv with all data.
#     ✅ Successfully updated: ICICI_BANK_LTD._predictions_lstm.csv
# ---> Processing INFOSYS_LIMITED
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\INFOSYS_LIMITED_predictions_lstm.csv with all data.
#     ✅ Successfully updated: INFOSYS_LIMITED_predictions_lstm.csv
# ---> Processing STATE_BANK_OF_INDIA
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\STATE_BANK_OF_INDIA_predictions_lstm.csv with all data.
#     ✅ Successfully updated: STATE_BANK_OF_INDIA_predictions_lstm.csv
# ---> Processing BHARTI_AIRTEL_LIMITED
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\BHARTI_AIRTEL_LIMITED_predictions_lstm.csv with all data.
#     ✅ Successfully updated: BHARTI_AIRTEL_LIMITED_predictions_lstm.csv
# ---> Processing ITC_LTD
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\ITC_LTD_predictions_lstm.csv with all data.
#     ✅ Successfully updated: ITC_LTD_predictions_lstm.csv
# ---> Processing LARSEN_&_TOUBRO_LTD.
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\LARSEN_&_TOUBRO_LTD._predictions_lstm.csv with all data.
#     ✅ Successfully updated: LARSEN_&_TOUBRO_LTD._predictions_lstm.csv
# ---> Processing HINDUSTAN_UNILEVER_LTD.
# Created a new file at X:\AGDrive\ADA-Timeseries project\Pred_Data\HINDUSTAN_UNILEVER_LTD._predictions_lstm.csv with all data.
#     ✅ Successfully updated: HINDUSTAN_UNILEVER_LTD._predictions_lstm.csv
#
# All processing complete.

# %%
import os
import pandas as pd
from lags_util import create_all_advanced_lags

# --- File Paths ---
predicted_data_folder = r"X:\AGDrive\ADA-Timeseries project\Pred_Data"
lagging_data_folder = r"X:\AGDrive\ADA-Timeseries project\Lag_Data"

# --- Loop Through All Equities to Generate Lag Features ---

print(f"\n{'='*80}")
print(f"📈 Generating lag features for all equities...")
print(f"{'='*80}")

# We just need the "basename" values from the map (e.g., "NIFTY_50")
for basename in ticker_to_basename.values():
    print(f"---> Processing {basename}")
    
    try:
        # 1. Construct the path to the prediction file (Input)
        #    (This assumes the output from your previous script)
        pred_file_name = f"{basename}_predictions_xgboost.csv"
        pred_file_path = os.path.join(predicted_data_folder, pred_file_name)

        # 2. Construct the path for the new lag file (Output)
        lag_file_name = f"{basename}_lagged.csv"
        lag_file_path = os.path.join(lagging_data_folder, lag_file_name)
        
        # 3. Read the prediction data
        data = pd.read_csv(pred_file_path, parse_dates=['Datetime'], index_col='Datetime')
        if data.index.tz is not None:
            data.index = data.index.tz_localize(None)

        # 4. Isolate the 'ActualPrice' column as the base for lags
        data_df = data[['ActualPrice']].copy()

        # 5. Create the advanced lag features
        full_lagged = create_all_advanced_lags(data_df)
        if full_lagged.index.tz is not None:
            full_lagged.index = full_lagged.index.tz_localize(None)

        # 6. Save the new lagged data to the Lag_Data folder
        full_lagged.to_csv(lag_file_path)
        print(f"    ✅ Successfully created: {lag_file_name}")

    except FileNotFoundError:
        print(f"    ⚠️  Skipping {basename}: Prediction file not found at {pred_file_path}")
    except Exception as e:
        print(f"    ❌ Error processing lags for {basename}: {e}")

print("\nAll lag feature generation complete.")
# Out:
# ================================================================================
# 📈 Generating lag features for all equities...
# ================================================================================
# ---> Processing NIFTY_50
#     ✅ Successfully created: NIFTY_50_lagged.csv
# ---> Processing NIFTY_BANK
#     ✅ Successfully created: NIFTY_BANK_lagged.csv
# ---> Processing NIFTY_IT
#     ✅ Successfully created: NIFTY_IT_lagged.csv
# ---> Processing NIFTY_PHARMA
#     ✅ Successfully created: NIFTY_PHARMA_lagged.csv
# ---> Processing NIFTY_FMCG
#     ✅ Successfully created: NIFTY_FMCG_lagged.csv
# ---> Processing NIFTY_AUTO
#     ✅ Successfully created: NIFTY_AUTO_lagged.csv
# ---> Processing NIFTY_METAL
#     ✅ Successfully created: NIFTY_METAL_lagged.csv
# ---> Processing NIFTY_REALTY
#     ✅ Successfully created: NIFTY_REALTY_lagged.csv
# ---> Processing NIFTY_ENERGY
#     ✅ Successfully created: NIFTY_ENERGY_lagged.csv
# ---> Processing NIFTY_FIN_SERVICE
#     ✅ Successfully created: NIFTY_FIN_SERVICE_lagged.csv
# ---> Processing RELIANCE_INDUSTRIES_LTD
#     ✅ Successfully created: RELIANCE_INDUSTRIES_LTD_lagged.csv
# ---> Processing TATA_CONSULTANCY_SERV_LT
#     ✅ Successfully created: TATA_CONSULTANCY_SERV_LT_lagged.csv
# ---> Processing SUN_PHARMACEUTICAL_IND_L
#     ⚠️  Skipping SUN_PHARMACEUTICAL_IND_L: Prediction file not found at X:\AGDrive\ADA-Timeseries project\Pred_Data\SUN_PHARMACEUTICAL_IND_L_predictions_xgboost.csv
# ---> Processing ICICI_BANK_LTD.
#     ✅ Successfully created: ICICI_BANK_LTD._lagged.csv
# ---> Processing INFOSYS_LIMITED
#     ✅ Successfully created: INFOSYS_LIMITED_lagged.csv
# ---> Processing STATE_BANK_OF_INDIA
#     ✅ Successfully created: STATE_BANK_OF_INDIA_lagged.csv
# ---> Processing BHARTI_AIRTEL_LIMITED
#     ✅ Successfully created: BHARTI_AIRTEL_LIMITED_lagged.csv
# ---> Processing ITC_LTD
#     ✅ Successfully created: ITC_LTD_lagged.csv
# ---> Processing LARSEN_&_TOUBRO_LTD.
#     ✅ Successfully created: LARSEN_&_TOUBRO_LTD._lagged.csv
# ---> Processing HINDUSTAN_UNILEVER_LTD.
#     ✅ Successfully created: HINDUSTAN_UNILEVER_LTD._lagged.csv
#
# All lag feature generation complete.
